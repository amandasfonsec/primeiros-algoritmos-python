# %% [markdown]
# # 🎮 Projeto Final — GameSelect
#
# Template de notebook **vazio com orientações**. Preencha cada seção conforme as instruções.

# %% [markdown]
# ## ✅ Checklist de Entrega
# - [ ] Descrição do problema e público-alvo
# - [ ] Carregamento do dataset `games_catalog_G4.csv`
# - [ ] Dicionário de dados
# - [ ] EDA (exploração, gráficos, estatísticas)
# - [ ] Limpeza (ausentes/outliers) e justificativas
# - [ ] Vetorização de gêneros (multi-hot)
# - [ ] Similaridade cosseno
# - [ ] Função de recomendação + casos de teste
# - [ ] Insights e próximos passos

# %% [markdown]
# ## 1. Descrição do Problema
# - Qual problema você quer resolver?
# - Quem é o usuário final?
# - Qual é o critério de sucesso (ex.: **recomendar 5 jogos similares** a um título dado)?
#
# **Escreva aqui:**
# - Quero ajudar os usuários a encontrarem jogos com base nos gêneros que eles já tenham jogado.
# - Jogadores que queiram explorar novos jogos.
# - Recomendar 5 jogos a aprtir de um título informado pelo programa.

# %% [markdown]
# ## 2. Carregando o Dataset
# Use o arquivo `https://raw.githubusercontent.com/fisicorj/aulacienciadedados/refs/heads/main/games_catalog_G4.csv`. Se estiver no Colab, faça upload ou monte o Drive.

# %% [markdown]
# Carregue as blibiotecas necessárias

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

GIT_HUB_URL = "https://raw.githubusercontent.com/fisicorj/aulacienciadedados/refs/heads/main/games_catalog_G4.csv"

# %%
df = pd.read_csv(GIT_HUB_URL)
print("Linhas x colunas:", df.shape)
df.head()
# Out:
# Linhas x colunas: (30, 8)
#             title                         genres platform   price  rating  \
# 0           Hades         Action,Roguelike,Indie       PC  235.71    4.11
# 1   Hollow Knight  Metroidvania,Indie,Platformer       PC   45.37    4.87
# 2          Skyrim       RPG,Open World,Adventure       PC  239.10    3.68
# 3        Terraria     Sandbox,Survival,Adventure       PC  278.49    4.40
# 4  Stardew Valley       Simulation,Farming,Indie       PC  143.16    3.82
#
#    reviews_count  release_year age_rating
# 0         216791          2022          E
# 1         348835          2020        16+
# 2         419954          2016        14+
# 3         185713          2015        16+
# 4          46521          2017        18+

# %% [markdown]
# ## 4. EDA — Análise Exploratória

# %% [markdown]
# ### 4.1 Estrutura e tipos

# %% [markdown]
# ### 4.2 Estatísticas descritivas

# %% [markdown]
# ### 4.3 Valores ausentes

# %% [markdown]
# ### 4.4 Distribuições e contagens (exemplos)

# %% [markdown]
# ### 4.5 Visualizações (use matplotlib)

# %% [markdown]
# ## 5. Limpeza de Dados (ausentes e outliers)
# Descreva o que foi feito e por quê.

# %% [markdown]
# ## 6. Preparação para Recomendação — Vetorização de Gêneros

# %% [markdown]
# Exploda a coluna `genres` e crie uma matriz **multi-hot** (uma coluna por gênero).

# %% [markdown]
# ## 7. Similaridade Cosseno

# %% [markdown]
# ## 8. Função de Recomendação

# %% [markdown]
# ## 9. Teste do Recomendador

# %% [markdown]
# ## 10. Visualização dos Resultados

# %% [markdown]
# ## 11. Insights e Próximos Passos
# Explique os principais achados e como você melhoraria o sistema.

# %% [markdown]
# - Quais gêneros mais influenciaram as recomendações?
# - Há viés de popularidade? Falta de metadados?
# - O que adicionar: descrições (TF-IDF), avaliações (colaborativo), peso por gênero etc.

# %% [markdown]
# ## 12. Apêndice (opcional)
# Registre aqui decisões de limpeza, funções auxiliares, versões de pacotes, etc.
